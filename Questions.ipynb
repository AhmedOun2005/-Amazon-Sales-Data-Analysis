# %%
import pandas as pd 
df = pd.read_csv('final_Amazon_set.csv')
df
# Out:
#                    Order ID       Date     Status Fulfilment Sales Channel   \
# 0       405-8078784-5731545  4/30/2022  Cancelled   Merchant      Amazon.in
# 1       171-9198151-1101146  4/30/2022    Shipped   Merchant      Amazon.in
# 2       404-0687676-7273146  4/30/2022    Shipped     Amazon      Amazon.in
# 3       403-9615377-8133951  4/30/2022  Cancelled   Merchant      Amazon.in
# 4       407-1069790-7240320  4/30/2022    Shipped     Amazon      Amazon.in
# ...                     ...        ...        ...        ...            ...
# 128964  406-6001380-7673107  5/31/2022    Shipped     Amazon      Amazon.in
# 128965  402-9551604-7544318  5/31/2022    Shipped     Amazon      Amazon.in
# 128966  407-9547469-3152358  5/31/2022    Shipped     Amazon      Amazon.in
# 128967  402-6184140-0545956  5/31/2022    Shipped     Amazon      Amazon.in
# 128968  408-7436540-8728312  5/31/2022    Shipped     Amazon      Amazon.in
#
# ...

# %%
df.columns
# Out:
# Index(['Order ID', 'Date', 'Status', 'Fulfilment', 'Sales Channel ',
#        'ship-service-level', 'Style', 'SKU', 'Category', 'Size', 'ASIN',
#        'Courier Status', 'Qty', 'Amount', 'ship-city', 'ship-state',
#        'ship-postal-code', 'B2B'],
#       dtype='object')

# %%
ss=df['Order ID'].drop_duplicates()
print(ss.count())
df['Order ID'].count()
# Out:
# 120378
# np.int64(128969)

# %%
df['Sales Channel '].value_counts()
# Out:
# Sales Channel
# Amazon.in     128845
# Non-Amazon       124
# Name: count, dtype: int64
